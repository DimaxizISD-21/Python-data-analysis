# %%
import pandas as pd
import pandas_profiling

# %%
df = pd.read_csv('coronavirus_dataset.csv')

# %%
df.profile_report()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.sample(5)
# Out:
#          dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 7346  22/02/2020   22      2  ...     RO                   ROU   19473936.0
# 4250  10/02/2020   10      2  ...     IR                   IRN   81800269.0
# 1452  01/04/2020    1      4  ...     KH                   KHM   16249798.0
# 6437  29/02/2020   29      2  ...     NG                   NGA  195874740.0
# 4682  21/01/2020   21      1  ...     IT                   ITA   60431283.0
#
# [5 rows x 10 columns]
