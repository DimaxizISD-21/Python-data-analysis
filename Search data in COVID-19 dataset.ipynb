# %%
from pandas import read_csv

df = read_csv("COVID-19.csv")

# %%
df.head()
# Out:
#       dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 0  02/04/2020    2      4  ...     AF                   AFG   37172386.0
# 1  01/04/2020    1      4  ...     AF                   AFG   37172386.0
# 2  31/03/2020   31      3  ...     AF                   AFG   37172386.0
# 3  30/03/2020   30      3  ...     AF                   AFG   37172386.0
# 4  29/03/2020   29      3  ...     AF                   AFG   37172386.0
#
# [5 rows x 10 columns]

# %%
df.tail(10)
# Out:
#          dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 8294  30/03/2020   30      3  ...     ZW                   ZWE   14439018.0
# 8295  29/03/2020   29      3  ...     ZW                   ZWE   14439018.0
# 8296  28/03/2020   28      3  ...     ZW                   ZWE   14439018.0
# 8297  27/03/2020   27      3  ...     ZW                   ZWE   14439018.0
# 8298  26/03/2020   26      3  ...     ZW                   ZWE   14439018.0
# 8299  25/03/2020   25      3  ...     ZW                   ZWE   14439018.0
# 8300  24/03/2020   24      3  ...     ZW                   ZWE   14439018.0
# 8301  23/03/2020   23      3  ...     ZW                   ZWE   14439018.0
# 8302  22/03/2020   22      3  ...     ZW                   ZWE   14439018.0
# 8303  21/03/2020   21      3  ...     ZW                   ZWE   14439018.0
#
# [10 rows x 10 columns]

# %%
df.count()
# Out:
# dateRep                    8304
# day                        8304
# month                      8304
# year                       8304
# cases                      8304
# deaths                     8304
# countriesAndTerritories    8304
# geoId                      8285
# countryterritoryCode       8230
# popData2018                8282
# dtype: int64

# %%
df.cases.max()
# Out:
# 27103

# %%
df.describe()
# Out:
#                day        month  ...       deaths   popData2018
# count  8304.000000  8304.000000  ...  8304.000000  8.282000e+03
# mean     17.016257     2.386561  ...     5.646797  6.745580e+07
# std       9.197688     1.249022  ...    49.718263  2.073221e+08
# min       1.000000     1.000000  ...   -18.000000  1.000000e+03
# 25%       9.000000     1.000000  ...     0.000000  4.089400e+06
# 50%      18.000000     3.000000  ...     0.000000  1.062716e+07
# 75%      25.000000     3.000000  ...     0.000000  4.672375e+07
# max      31.000000    12.000000  ...  1059.000000  1.392730e+09
#
# [8 rows x 6 columns]

# %%
df.corr()
# Out:
#                   day     month      year     cases    deaths  popData2018
# day          1.000000  0.108683 -0.137127  0.035665  0.028676    -0.036123
# month        0.108683  1.000000 -0.694205  0.070711  0.068367    -0.051141
# year        -0.137127 -0.694205  1.000000  0.011781  0.010244    -0.007779
# cases        0.035665  0.070711  0.011781  1.000000  0.755184     0.109668
# deaths       0.028676  0.068367  0.010244  0.755184  1.000000     0.063332
# popData2018 -0.036123 -0.051141 -0.007779  0.109668  0.063332     1.000000

# %%
df.deaths.max()
# Out:
# 1059

# %%
df.countriesAndTerritories.nunique()
# Out:
# 204

# %%
df.countriesAndTerritories.count()
# Out:
# 8304

# %%
df2 = df[df['cases']>=10]
df2.count()
# Out:
# dateRep                    2007
# day                        2007
# month                      2007
# year                       2007
# cases                      2007
# deaths                     2007
# countriesAndTerritories    2007
# geoId                      2007
# countryterritoryCode       1994
# popData2018                2007
# dtype: int64

# %%
df2[df2['countriesAndTerritories']=='Vietnam']
# Out:
#          dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 8190  29/03/2020   29      3  ...     VN                   VNM   95540395.0
# 8191  28/03/2020   28      3  ...     VN                   VNM   95540395.0
# 8193  26/03/2020   26      3  ...     VN                   VNM   95540395.0
# 8194  25/03/2020   25      3  ...     VN                   VNM   95540395.0
# 8196  23/03/2020   23      3  ...     VN                   VNM   95540395.0
# 8200  19/03/2020   19      3  ...     VN                   VNM   95540395.0
#
# [6 rows x 10 columns]

# %%
df2[df2['countriesAndTerritories']=='Russia']
# Out:
#          dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 6467  02/04/2020    2      4  ...     RU                   RUS  144478050.0
# 6468  01/04/2020    1      4  ...     RU                   RUS  144478050.0
# 6469  31/03/2020   31      3  ...     RU                   RUS  144478050.0
# 6470  30/03/2020   30      3  ...     RU                   RUS  144478050.0
# 6471  29/03/2020   29      3  ...     RU                   RUS  144478050.0
# 6472  28/03/2020   28      3  ...     RU                   RUS  144478050.0
# 6473  27/03/2020   27      3  ...     RU                   RUS  144478050.0
# 6474  26/03/2020   26      3  ...     RU                   RUS  144478050.0
# 6475  25/03/2020   25      3  ...     RU                   RUS  144478050.0
# 6477  23/03/2020   23      3  ...     RU                   RUS  144478050.0
# 6478  22/03/2020   22      3  ...     RU                   RUS  144478050.0
# ...

# %%
df2[df2['countriesAndTerritories']=='Ukraine']
# Out:
#          dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 7808  02/04/2020    2      4  ...     UA                   UKR   44622516.0
# 7809  01/04/2020    1      4  ...     UA                   UKR   44622516.0
# 7810  31/03/2020   31      3  ...     UA                   UKR   44622516.0
# 7811  30/03/2020   30      3  ...     UA                   UKR   44622516.0
# 7812  29/03/2020   29      3  ...     UA                   UKR   44622516.0
# 7813  28/03/2020   28      3  ...     UA                   UKR   44622516.0
# 7814  27/03/2020   27      3  ...     UA                   UKR   44622516.0
# 7815  26/03/2020   26      3  ...     UA                   UKR   44622516.0
# 7816  25/03/2020   25      3  ...     UA                   UKR   44622516.0
# 7817  24/03/2020   24      3  ...     UA                   UKR   44622516.0
# 7819  22/03/2020   22      3  ...     UA                   UKR   44622516.0
#
# [11 rows x 10 columns]

# %%
df2[df2['countriesAndTerritories']=='Moldova']
# Out:
#          dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 5059  02/04/2020    2      4  ...     MD                   MDA    3545883.0
# 5060  01/04/2020    1      4  ...     MD                   MDA    3545883.0
# 5061  31/03/2020   31      3  ...     MD                   MDA    3545883.0
# 5062  30/03/2020   30      3  ...     MD                   MDA    3545883.0
# 5063  29/03/2020   29      3  ...     MD                   MDA    3545883.0
# 5064  28/03/2020   28      3  ...     MD                   MDA    3545883.0
# 5065  27/03/2020   27      3  ...     MD                   MDA    3545883.0
# 5066  26/03/2020   26      3  ...     MD                   MDA    3545883.0
# 5067  25/03/2020   25      3  ...     MD                   MDA    3545883.0
# 5068  24/03/2020   24      3  ...     MD                   MDA    3545883.0
# 5069  23/03/2020   23      3  ...     MD                   MDA    3545883.0
# ...

# %%
df2[df2['countriesAndTerritories']=='Italy']
# Out:
#          dateRep  day  month  ...  geoId  countryterritoryCode  popData2018
# 4024  02/04/2020    2      4  ...     IT                   ITA   60431283.0
# 4025  01/04/2020    1      4  ...     IT                   ITA   60431283.0
# 4026  31/03/2020   31      3  ...     IT                   ITA   60431283.0
# 4027  30/03/2020   30      3  ...     IT                   ITA   60431283.0
# 4028  29/03/2020   29      3  ...     IT                   ITA   60431283.0
# 4029  28/03/2020   28      3  ...     IT                   ITA   60431283.0
# 4030  27/03/2020   27      3  ...     IT                   ITA   60431283.0
# 4031  26/03/2020   26      3  ...     IT                   ITA   60431283.0
# 4032  25/03/2020   25      3  ...     IT                   ITA   60431283.0
# 4033  24/03/2020   24      3  ...     IT                   ITA   60431283.0
# 4034  23/03/2020   23      3  ...     IT                   ITA   60431283.0
# ...

# %%
df2[df2['countriesAndTerritories']=='Ukraine'].count()
# Out:
# dateRep                    11
# day                        11
# month                      11
# year                       11
# cases                      11
# deaths                     11
# countriesAndTerritories    11
# geoId                      11
# countryterritoryCode       11
# popData2018                11
# dtype: int64
